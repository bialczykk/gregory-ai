# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import os

import re
from collections import Counter
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk
from nltk.util import ngrams
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from wordcloud import WordCloud
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# # Relative n-grams frequencies
#
# In this notebook we calculate which words appear specifically often in one class, and very rarely in other class. To calculate relative frequencies, we first count the number of documents in which an n-gram appear in per each class and represent this value as a percentage of all documents of a given class.
#
# After that, the difference between appearance ratio of both classes is calculated and n-grams with highest difference scores printed out.
#
# This allows to see specific words / bi-grams / tri-grams that appear mostly or only in one of the classes.
#
#
#
# **Limitations:**
# - Current low number of labeled samples does can cause the results not relevant due to the number of unlabeled data
# - Imbalance between classes -- majority of labeled observations belong to "relevant" class. "non-relevant" class is misrepresented, therefore, we cannot be sure about the results of this analysis. The risk is that the calculated work-frequencies are not represented in the population.

# %% [markdown]
# ## Loading Data

# %%
articles_path = '/Users/kuba/Desktop/PBL/EDA/articles/articles_01-01-2024_14h39m35s.csv'
trials_path = '/Users/kuba/Desktop/PBL/EDA/trials/trials_01-01-2024_14h39m35s.csv'

articles = pd.read_csv(articles_path, index_col=0)
trials = pd.read_csv(trials_path, index_col=0)

# %% [markdown]
# ## Utilities

# %%
# Function to create n-grams and their frequencies
def n_gram_frequency(df, text_column, ngram_range=(2, 2), col_name='n-gram'):
    # Instantiate CountVectorizer for n-grams with binary=True
    vectorizer = CountVectorizer(ngram_range=ngram_range, binary=True)
    
    # Apply the vectorizer to the text documents
    X = vectorizer.fit_transform(df[text_column])
    
    # Sum up the occurrences of each n-gram across all documents
    frequencies = X.sum(axis=0)
    
    # Create a DataFrame with n-grams and their frequencies
    n_gram_df = pd.DataFrame(frequencies.T, index=vectorizer.get_feature_names_out(), columns=['frequency'])
    n_gram_df = n_gram_df.reset_index().rename(columns={'index': col_name})
    
    return n_gram_df

# %% [markdown]
# ## Preprocessing

# %%
# drop rows with missing values in summary column
articles.dropna(subset=['summary'], inplace=True)
articles.dropna(subset=['relevant'], inplace=True)

# %%
# for summaries that have doi, keep only eveyrhting in the string after doi
articles['summary'] = articles['summary'].apply(lambda x: x.lower().split('abstract')[1] if 'abstract' in x.lower() else x)

# %%
def preprocess_lemma(text):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()

    if isinstance(text, list):
        words = [word for sublist in text for word in word_tokenize(sublist.lower())]
    else:
        text = text.translate(str.maketrans('', '', string.punctuation))
        words = word_tokenize(text.lower())

    return ' '.join([lemmatizer.lemmatize(word) for word in words if word not in stop_words and word.isalpha()])

# %%
articles.summary = articles.summary.apply(preprocess_lemma)

# %% [markdown]
# ## Single word relative frequency analysis

# %%
word_freq_df = n_gram_frequency(articles, 'summary', ngram_range=(1, 1), col_name='word')

word_freq_rel_df = n_gram_frequency(articles[articles.relevant == True], 'summary', ngram_range=(1, 1), col_name='word')

word_freq_nrel_df = n_gram_frequency(articles[articles.relevant == False], 'summary', ngram_range=(1, 1), col_name='word')

word_freq_df = word_freq_df.merge(word_freq_rel_df.rename(columns={"frequency":"freq_relevant"}), left_on='word', right_on='word', how='left')
word_freq_df = word_freq_df.merge(word_freq_nrel_df.rename(columns={"frequency":"freq_non_relevant"}), left_on='word', right_on='word', how='left')

# fill na with 0 for words that are not in relevant or non relevant
word_freq_df.fillna(0, inplace=True)

word_freq_df['freq_relevant_ratio'] = word_freq_df['freq_relevant']/articles[articles.relevant == True].shape[0]
word_freq_df['freq_non_relevant_ratio'] = word_freq_df['freq_non_relevant']/articles[articles.relevant == False].shape[0]

word_freq_df['diff'] = np.abs(word_freq_df['freq_relevant_ratio'] - word_freq_df['freq_non_relevant_ratio'])

word_freq_df['relevant_class'] = word_freq_df['freq_relevant_ratio'] > word_freq_df['freq_non_relevant_ratio']

# %%
word_freq_df[word_freq_df['relevant_class'] == True].sort_values(by='diff', ascending=False).head(20)
# Out:
#                     word  frequency  freq_relevant  freq_non_relevant  \
# 1688                cell        450          419.0               31.0
# 7186               mouse        279          271.0                8.0
# 3497              effect        432          391.0               41.0
# 10378          sclerosis        783          669.0              114.0
# 4051        experimental        231          228.0                3.0
# 949           autoimmune        297          280.0               17.0
# 7324            multiple        799          680.0              119.0
# 7553             nervous        257          245.0               12.0
# 2877       demyelination        210          207.0                3.0
# 1727             central        268          253.0               15.0
# 11428             system        319          293.0               26.0
# 7048               model        338          308.0               30.0
# 11621        therapeutic        309          284.0               25.0
# 3653   encephalomyelitis        181          180.0                1.0
# 3423                 eae        180          179.0                1.0
# 7365              myelin        197          192.0                5.0
# 8991           potential        280          256.0               24.0
# 1991                 cns        203          193.0               10.0
# 8038     oligodendrocyte        148          146.0                2.0
# 3147             disease        583          493.0               90.0
#
#        freq_relevant_ratio  freq_non_relevant_ratio      diff  relevant_class
# 1688              0.488915                 0.143519  0.345396            True
# 7186              0.316219                 0.037037  0.279182            True
# 3497              0.456243                 0.189815  0.266428            True
# 10378             0.780630                 0.527778  0.252852            True
# 4051              0.266044                 0.013889  0.252155            True
# 949               0.326721                 0.078704  0.248017            True
# 7324              0.793466                 0.550926  0.242540            True
# 7553              0.285881                 0.055556  0.230325            True
# 2877              0.241540                 0.013889  0.227651            True
# 1727              0.295216                 0.069444  0.225771            True
# 11428             0.341890                 0.120370  0.221520            True
# 7048              0.359393                 0.138889  0.220504            True
# 11621             0.331389                 0.115741  0.215648            True
# 3653              0.210035                 0.004630  0.205405            True
# 3423              0.208868                 0.004630  0.204239            True
# 7365              0.224037                 0.023148  0.200889            True
# 8991              0.298716                 0.111111  0.187605            True
# 1991              0.225204                 0.046296  0.178908            True
# 8038              0.170362                 0.009259  0.161102            True
# 3147              0.575263                 0.416667  0.158596            True

# %%
word_freq_df[word_freq_df['relevant_class'] == False].sort_values(by='diff', ascending=False).head(20)
# Out:
#               word  frequency  freq_relevant  freq_non_relevant  \
# 1017    background        208          136.0               72.0
# 8441       patient        382          275.0              107.0
# 1619          case         69           33.0               36.0
# 281            age         93           54.0               39.0
# 5497      included         96           57.0               39.0
# 3023     diagnosis         48           21.0               27.0
# 5581     infection         52           25.0               27.0
# 450          among         84           51.0               33.0
# 1596          care         30            8.0               22.0
# 5022        higher        102           66.0               36.0
# 10173         risk         86           54.0               32.0
# 9618          rate         82           51.0               31.0
# 12671         year        117           79.0               38.0
# 9951        report         60           34.0               26.0
# 11401     syndrome         42           20.0               22.0
# 8561     performed        102           68.0               34.0
# 486       analysis        192          140.0               52.0
# 12329  vaccination         24            6.0               18.0
# 6358    literature         44           22.0               22.0
# 2225    conclusion        154          110.0               44.0
#
#        freq_relevant_ratio  freq_non_relevant_ratio      diff  relevant_class
# 1017              0.158693                 0.333333  0.174640           False
# 8441              0.320887                 0.495370  0.174484           False
# 1619              0.038506                 0.166667  0.128160           False
# 281               0.063011                 0.180556  0.117545           False
# 5497              0.066511                 0.180556  0.114044           False
# 3023              0.024504                 0.125000  0.100496           False
# 5581              0.029172                 0.125000  0.095828           False
# 450               0.059510                 0.152778  0.093268           False
# 1596              0.009335                 0.101852  0.092517           False
# 5022              0.077013                 0.166667  0.089654           False
# 10173             0.063011                 0.148148  0.085138           False
# 9618              0.059510                 0.143519  0.084009           False
# 12671             0.092182                 0.175926  0.083744           False
# 9951              0.039673                 0.120370  0.080697           False
# 11401             0.023337                 0.101852  0.078515           False
# 8561              0.079347                 0.157407  0.078061           False
# 486               0.163361                 0.240741  0.077380           False
# 12329             0.007001                 0.083333  0.076332           False
# 6358              0.025671                 0.101852  0.076181           False
# 2225              0.128355                 0.203704  0.075349           False

# %% [markdown]
# ### What words appear only in one class very often?

# %%
# relevant class
word_freq_df[(word_freq_df['relevant_class'] == True) & (word_freq_df['freq_non_relevant'] == 0)].sort_values(by='diff', ascending=False).head(20)
# Out:
#                     word  frequency  freq_relevant  freq_non_relevant  \
# 5596        infiltration         66           66.0                0.0
# 1001                axon         64           64.0                0.0
# 2611           cuprizone         56           56.0                0.0
# 9275            promotes         43           43.0                0.0
# 10629             sheath         37           37.0                0.0
# 7606   neuroinflammatory         37           37.0                0.0
# 365           alleviated         36           36.0                0.0
# 1322          bloodbrain         34           34.0                0.0
# 9224          progenitor         33           33.0                0.0
# 1062             balance         33           33.0                0.0
# 9273            promoted         33           33.0                0.0
# 3775              enzyme         33           33.0                0.0
# 6667              mature         33           33.0                0.0
# 1105                 bbb         32           32.0                0.0
# 6936           migration         31           31.0                0.0
# 9791        regenerative         31           31.0                0.0
# 2816        degeneration         30           30.0                0.0
# 4697        glycoprotein         30           30.0                0.0
# 11027           staining         29           29.0                0.0
# 5645          inhibitory         26           26.0                0.0
#
#        freq_relevant_ratio  freq_non_relevant_ratio      diff  relevant_class
# 5596              0.077013                      0.0  0.077013            True
# 1001              0.074679                      0.0  0.074679            True
# 2611              0.065344                      0.0  0.065344            True
# 9275              0.050175                      0.0  0.050175            True
# 10629             0.043174                      0.0  0.043174            True
# 7606              0.043174                      0.0  0.043174            True
# 365               0.042007                      0.0  0.042007            True
# 1322              0.039673                      0.0  0.039673            True
# 9224              0.038506                      0.0  0.038506            True
# 1062              0.038506                      0.0  0.038506            True
# 9273              0.038506                      0.0  0.038506            True
# 3775              0.038506                      0.0  0.038506            True
# 6667              0.038506                      0.0  0.038506            True
# 1105              0.037340                      0.0  0.037340            True
# 6936              0.036173                      0.0  0.036173            True
# 9791              0.036173                      0.0  0.036173            True
# 2816              0.035006                      0.0  0.035006            True
# 4697              0.035006                      0.0  0.035006            True
# 11027             0.033839                      0.0  0.033839            True
# 5645              0.030338                      0.0  0.030338            True

# %%
# non-relevant class
word_freq_df[(word_freq_df['relevant_class'] == False) & (word_freq_df['freq_relevant'] == 0)].sort_values(by='diff', ascending=False).head(20)
# Out:
#                  word  frequency  freq_relevant  freq_non_relevant  \
# 8198   osteoarthritis          6            0.0                6.0
# 9210     professional          6            0.0                6.0
# 12328      vaccinated          5            0.0                5.0
# 8328       palliative          5            0.0                5.0
# 7766           nodule          5            0.0                5.0
# 895         attending          4            0.0                4.0
# 1371             bony          4            0.0                4.0
# 8620         personal          4            0.0                4.0
# 11068            stay          4            0.0                4.0
# 9743       recurrence          4            0.0                4.0
# 1598        caregiver          4            0.0                4.0
# 12025        tuberous          4            0.0                4.0
# 1614        cartilage          4            0.0                4.0
# 8124          opioids          3            0.0                3.0
# 5440        implement          3            0.0                3.0
# 12250    unvaccinated          3            0.0                3.0
# 7943               oa          3            0.0                3.0
# 10095        returned          3            0.0                3.0
# 9568        radiology          3            0.0                3.0
# 10537      separately          3            0.0                3.0
#
#        freq_relevant_ratio  freq_non_relevant_ratio      diff  relevant_class
# 8198                   0.0                 0.027778  0.027778           False
# 9210                   0.0                 0.027778  0.027778           False
# 12328                  0.0                 0.023148  0.023148           False
# 8328                   0.0                 0.023148  0.023148           False
# 7766                   0.0                 0.023148  0.023148           False
# 895                    0.0                 0.018519  0.018519           False
# 1371                   0.0                 0.018519  0.018519           False
# 8620                   0.0                 0.018519  0.018519           False
# 11068                  0.0                 0.018519  0.018519           False
# 9743                   0.0                 0.018519  0.018519           False
# 1598                   0.0                 0.018519  0.018519           False
# 12025                  0.0                 0.018519  0.018519           False
# 1614                   0.0                 0.018519  0.018519           False
# 8124                   0.0                 0.013889  0.013889           False
# 5440                   0.0                 0.013889  0.013889           False
# 12250                  0.0                 0.013889  0.013889           False
# 7943                   0.0                 0.013889  0.013889           False
# 10095                  0.0                 0.013889  0.013889           False
# 9568                   0.0                 0.013889  0.013889           False
# 10537                  0.0                 0.013889  0.013889           False

# %% [markdown]
# ### Most frequent words in each class (absolute frequency)

# %%
# relevant class
word_freq_df[word_freq_df.relevant_class == True].sort_values(by='freq_relevant', ascending=False).head(20)[['word', 'freq_relevant']].reset_index(drop=True)
# Out:
#             word  freq_relevant
# 0       multiple          680.0
# 1      sclerosis          669.0
# 2        disease          493.0
# 3          study          467.0
# 4           cell          419.0
# 5      treatment          392.0
# 6         effect          391.0
# 7          model          308.0
# 8         system          293.0
# 9    therapeutic          284.0
# 10    autoimmune          280.0
# 11         mouse          271.0
# 12      clinical          267.0
# 13        result          263.0
# 14     potential          256.0
# 15       central          253.0
# 16       nervous          245.0
# 17  experimental          228.0
# 18          role          222.0
# 19          also          217.0

# %%
# non-relevant class
word_freq_df[word_freq_df.relevant_class == False].sort_values(by='freq_non_relevant', ascending=False).head(20)[['word', 'freq_non_relevant']].reset_index(drop=True)
# Out:
#            word  freq_non_relevant
# 0       patient              107.0
# 1    background               72.0
# 2      analysis               52.0
# 3           may               50.0
# 4    associated               49.0
# 5   significant               45.0
# 6    conclusion               44.0
# 7          data               43.0
# 8      compared               43.0
# 9     including               42.0
# 10          age               39.0
# 11     included               39.0
# 12         year               38.0
# 13       method               37.0
# 14     disorder               36.0
# 15         case               36.0
# 16       higher               36.0
# 17    performed               34.0
# 18          one               34.0
# 19      outcome               33.0

# %% [markdown]
# ## Bi-grams relative frequency analysis

# %%
bi_gram_df = n_gram_frequency(articles, 'summary', col_name='bi-gram')

# %%
bi_gram_rel_df = n_gram_frequency(articles[articles.relevant == True], 'summary', col_name='bi-gram')

# %%
bi_gram_nrel_df = n_gram_frequency(articles[articles.relevant == False], 'summary', col_name='bi-gram')

# %%
bi_gram_df = bi_gram_df.merge(bi_gram_rel_df.rename(columns={"frequency": "freq_relevant"}), left_on='bi-gram', right_on='bi-gram', how='left')
bi_gram_df = bi_gram_df.merge(bi_gram_nrel_df.rename(columns={"frequency": "freq_non_relevant"}), left_on='bi-gram', right_on='bi-gram', how='left')

# fill na with 0 for bi-grams that are not in relevant or non-relevant
bi_gram_df.fillna(0, inplace=True)

bi_gram_df['freq_relevant_ratio'] = bi_gram_df['freq_relevant'] / articles[articles.relevant == True].shape[0]
bi_gram_df['freq_non_relevant_ratio'] = bi_gram_df['freq_non_relevant'] / articles[articles.relevant == False].shape[0]

bi_gram_df['diff'] = np.abs(bi_gram_df['freq_relevant_ratio'] - bi_gram_df['freq_non_relevant_ratio'])

bi_gram_df['relevant_class'] = bi_gram_df['freq_relevant_ratio'] > bi_gram_df['freq_non_relevant_ratio']

# %%
bi_gram_df[bi_gram_df['relevant_class'] == True].sort_values(by='diff', ascending=False).head(20)
# Out:
#                             bi-gram  frequency  freq_relevant  \
# 50317            multiple sclerosis        752          656.0
# 11220               central nervous        243          233.0
# 51451                nervous system        251          239.0
# 27914       experimental autoimmune        188          186.0
# 6749   autoimmune encephalomyelitis        179          178.0
# 25665         encephalomyelitis eae        149          148.0
# 78011                    system cns        128          125.0
# 23864                     eae mouse         96           95.0
# 74445                   spinal cord        125          117.0
# 4205                   animal model         95           91.0
# 49556                   mouse model         90           86.0
# 75050                     stem cell         70           69.0
# 6743             autoimmune disease         99           92.0
# 51632     neurodegenerative disease         81           77.0
# 19214         demyelinating disease         71           68.0
# 21633               disease central         61           59.0
# 35820                   immune cell         89           81.0
# 59699         potential therapeutic         51           50.0
# 79378            therapeutic effect         50           49.0
# 48363                model multiple         47           46.0
#
#        freq_non_relevant  freq_relevant_ratio  freq_non_relevant_ratio  \
# 50317               96.0             0.765461                 0.444444
# 11220               10.0             0.271879                 0.046296
# 51451               12.0             0.278880                 0.055556
# 27914                2.0             0.217036                 0.009259
# 6749                 1.0             0.207701                 0.004630
# 25665                1.0             0.172695                 0.004630
# 78011                3.0             0.145858                 0.013889
# 23864                1.0             0.110852                 0.004630
# 74445                8.0             0.136523                 0.037037
# 4205                 4.0             0.106184                 0.018519
# 49556                4.0             0.100350                 0.018519
# 75050                1.0             0.080513                 0.004630
# 6743                 7.0             0.107351                 0.032407
# 51632                4.0             0.089848                 0.018519
# 19214                3.0             0.079347                 0.013889
# 21633                2.0             0.068845                 0.009259
# 35820                8.0             0.094516                 0.037037
# 59699                1.0             0.058343                 0.004630
# 79378                1.0             0.057176                 0.004630
# 48363                1.0             0.053676                 0.004630
#
#            diff  relevant_class
# 50317  0.321016            True
# 11220  0.225582            True
# 51451  0.223324            True
# 27914  0.207777            True
# 6749   0.203072            True
# 25665  0.168066            True
# 78011  0.131969            True
# 23864  0.106222            True
# 74445  0.099486            True
# 4205   0.087666            True
# 49556  0.081832            True
# 75050  0.075884            True
# 6743   0.074944            True
# 51632  0.071330            True
# 19214  0.065458            True
# 21633  0.059586            True
# 35820  0.057479            True
# 59699  0.053713            True
# 79378  0.052547            True
# 48363  0.049046            True

# %%
bi_gram_df[bi_gram_df['relevant_class'] == False].sort_values(by='diff', ascending=False).head(20)
# Out:
#                       bi-gram  frequency  freq_relevant  freq_non_relevant  \
# 70744          sclerosis pwms         22            8.0               14.0
# 57364         people multiple         28           14.0               14.0
# 43731     logistic regression         14            4.0               10.0
# 33605         healthy control         29           16.0               13.0
# 78198       systematic review         21           10.0               11.0
# 10054       case presentation          8            0.0                8.0
# 67823    respiratory syndrome         13            4.0                9.0
# 1392        acute respiratory         15            6.0                9.0
# 16047     coronavirus disease         11            3.0                8.0
# 72112            severe acute         12            4.0                8.0
# 77845    syndrome coronavirus          9            2.0                7.0
# 53821              odds ratio          9            2.0                7.0
# 82477      trial registration          9            2.0                7.0
# 63431            quality life         39           26.0               13.0
# 73124  significant difference         35           23.0               12.0
# 34096             higher risk          6            0.0                6.0
# 75975          study included         11            4.0                7.0
# 37691          increased risk         16            8.0                8.0
# 2418                 age year         26           16.0               10.0
# 13249            cohort study          9            3.0                6.0
#
#        freq_relevant_ratio  freq_non_relevant_ratio      diff  relevant_class
# 70744             0.009335                 0.064815  0.055480           False
# 57364             0.016336                 0.064815  0.048479           False
# 43731             0.004667                 0.046296  0.041629           False
# 33605             0.018670                 0.060185  0.041515           False
# 78198             0.011669                 0.050926  0.039257           False
# 10054             0.000000                 0.037037  0.037037           False
# 67823             0.004667                 0.041667  0.036999           False
# 1392              0.007001                 0.041667  0.034665           False
# 16047             0.003501                 0.037037  0.033536           False
# 72112             0.004667                 0.037037  0.032370           False
# 77845             0.002334                 0.032407  0.030074           False
# 53821             0.002334                 0.032407  0.030074           False
# 82477             0.002334                 0.032407  0.030074           False
# 63431             0.030338                 0.060185  0.029847           False
# 73124             0.026838                 0.055556  0.028718           False
# 34096             0.000000                 0.027778  0.027778           False
# 75975             0.004667                 0.032407  0.027740           False
# 37691             0.009335                 0.037037  0.027702           False
# 2418              0.018670                 0.046296  0.027627           False
# 13249             0.003501                 0.027778  0.024277           False

# %% [markdown]
# ### Which bi grams appear only in one class?

# %%
# relevant class
bi_gram_df[(bi_gram_df['relevant_class'] == True) & (bi_gram_df['freq_non_relevant'] == 0)].sort_values(by='diff', ascending=False).head(20)
# Out:
#                             bi-gram  frequency  freq_relevant  \
# 23858                     eae model         41           41.0
# 46600              mesenchymal stem         36           36.0
# 50643                 myelin sheath         36           36.0
# 10672             cell infiltration         35           35.0
# 8748             bloodbrain barrier         34           34.0
# 50606        myelin oligodendrocyte         33           33.0
# 70425          sclerosis autoimmune         30           30.0
# 10759                      cell msc         30           30.0
# 50634                 myelin repair         29           29.0
# 10801                     cell opcs         28           28.0
# 61395               progenitor cell         28           28.0
# 23734                    eae animal         25           25.0
# 54060  oligodendrocyte glycoprotein         25           25.0
# 54114    oligodendrocyte progenitor         25           25.0
# 58734                play important         25           25.0
# 48281            model experimental         24           24.0
# 7435                    barrier bbb         24           24.0
# 45370        mature oligodendrocyte         23           23.0
# 12569                clinical score         22           22.0
# 65915               regulatory cell         21           21.0
#
#        freq_non_relevant  freq_relevant_ratio  freq_non_relevant_ratio  \
# 23858                0.0             0.047841                      0.0
# 46600                0.0             0.042007                      0.0
# 50643                0.0             0.042007                      0.0
# 10672                0.0             0.040840                      0.0
# 8748                 0.0             0.039673                      0.0
# 50606                0.0             0.038506                      0.0
# 70425                0.0             0.035006                      0.0
# 10759                0.0             0.035006                      0.0
# 50634                0.0             0.033839                      0.0
# 10801                0.0             0.032672                      0.0
# 61395                0.0             0.032672                      0.0
# 23734                0.0             0.029172                      0.0
# 54060                0.0             0.029172                      0.0
# 54114                0.0             0.029172                      0.0
# 58734                0.0             0.029172                      0.0
# 48281                0.0             0.028005                      0.0
# 7435                 0.0             0.028005                      0.0
# 45370                0.0             0.026838                      0.0
# 12569                0.0             0.025671                      0.0
# 65915                0.0             0.024504                      0.0
#
#            diff  relevant_class
# 23858  0.047841            True
# 46600  0.042007            True
# 50643  0.042007            True
# 10672  0.040840            True
# 8748   0.039673            True
# 50606  0.038506            True
# 70425  0.035006            True
# 10759  0.035006            True
# 50634  0.033839            True
# 10801  0.032672            True
# 61395  0.032672            True
# 23734  0.029172            True
# 54060  0.029172            True
# 54114  0.029172            True
# 58734  0.029172            True
# 48281  0.028005            True
# 7435   0.028005            True
# 45370  0.026838            True
# 12569  0.025671            True
# 65915  0.024504            True

# %%
# non-relevant class
bi_gram_df[(bi_gram_df['relevant_class'] == False) & (bi_gram_df['freq_relevant'] == 0)].sort_values(by='diff', ascending=False).head(20)
# Out:
#                         bi-gram  frequency  freq_relevant  freq_non_relevant  \
# 10054         case presentation          8            0.0                8.0
# 34096               higher risk          6            0.0                6.0
# 55571           palliative care          5            0.0                5.0
# 14347       computed tomography          4            0.0                4.0
# 62357        prospective cohort          4            0.0                4.0
# 82656        tuberous sclerosis          4            0.0                4.0
# 84600              vaccine dose          3            0.0                3.0
# 31173          fully vaccinated          3            0.0                3.0
# 79928             third vaccine          3            0.0                3.0
# 12479        clinical diagnosis          3            0.0                3.0
# 77990         system associated          3            0.0                3.0
# 73187  significant relationship          3            0.0                3.0
# 53400        objective evaluate          3            0.0                3.0
# 71214               second dose          3            0.0                3.0
# 34038          higher education          3            0.0                3.0
# 13667            compared adult          3            0.0                3.0
# 20956    differential diagnosis          3            0.0                3.0
# 49846          mrna vaccination          3            0.0                3.0
# 13551          commonly present          3            0.0                3.0
# 74222            specific brain          3            0.0                3.0
#
#        freq_relevant_ratio  freq_non_relevant_ratio      diff  relevant_class
# 10054                  0.0                 0.037037  0.037037           False
# 34096                  0.0                 0.027778  0.027778           False
# 55571                  0.0                 0.023148  0.023148           False
# 14347                  0.0                 0.018519  0.018519           False
# 62357                  0.0                 0.018519  0.018519           False
# 82656                  0.0                 0.018519  0.018519           False
# 84600                  0.0                 0.013889  0.013889           False
# 31173                  0.0                 0.013889  0.013889           False
# 79928                  0.0                 0.013889  0.013889           False
# 12479                  0.0                 0.013889  0.013889           False
# 77990                  0.0                 0.013889  0.013889           False
# 73187                  0.0                 0.013889  0.013889           False
# 53400                  0.0                 0.013889  0.013889           False
# 71214                  0.0                 0.013889  0.013889           False
# 34038                  0.0                 0.013889  0.013889           False
# 13667                  0.0                 0.013889  0.013889           False
# 20956                  0.0                 0.013889  0.013889           False
# 49846                  0.0                 0.013889  0.013889           False
# 13551                  0.0                 0.013889  0.013889           False
# 74222                  0.0                 0.013889  0.013889           False

# %% [markdown]
# ### Most frequent bi-grams in each class (absolute frequency)

# %%
# relevant class
bi_gram_df[bi_gram_df.relevant_class == True].sort_values(by='freq_relevant', ascending=False).head(20)[['bi-gram', 'freq_relevant']].reset_index(drop=True)
# Out:
#                          bi-gram  freq_relevant
# 0             multiple sclerosis          656.0
# 1                 nervous system          239.0
# 2                central nervous          233.0
# 3        experimental autoimmune          186.0
# 4   autoimmune encephalomyelitis          178.0
# 5          encephalomyelitis eae          148.0
# 6                     system cns          125.0
# 7                    spinal cord          117.0
# 8                      eae mouse           95.0
# 9             autoimmune disease           92.0
# 10                  animal model           91.0
# 11                   mouse model           86.0
# 12                   immune cell           81.0
# 13     neurodegenerative disease           77.0
# 14                clinical trial           73.0
# 15                     stem cell           69.0
# 16         demyelinating disease           68.0
# 17              disease multiple           61.0
# 18               disease central           59.0
# 19               immune response           50.0

# %%
# non-relevant class
bi_gram_df[bi_gram_df.relevant_class == False].sort_values(by='freq_non_relevant', ascending=False).head(20)[['bi-gram', 'freq_non_relevant']].reset_index(drop=True)
# Out:
#                         bi-gram  freq_non_relevant
# 0               people multiple               14.0
# 1                sclerosis pwms               14.0
# 2                  quality life               13.0
# 3               healthy control               13.0
# 4        significant difference               12.0
# 5             systematic review               11.0
# 6                 adverse event               10.0
# 7           logistic regression               10.0
# 8                      age year               10.0
# 9             disability status                9.0
# 10     diseasemodifying therapy                9.0
# 11         respiratory syndrome                9.0
# 12          expanded disability                9.0
# 13            acute respiratory                9.0
# 14  relapsingremitting multiple                8.0
# 15             compared control                8.0
# 16           magnetic resonance                8.0
# 17             disease activity                8.0
# 18          coronavirus disease                8.0
# 19               increased risk                8.0

# %% [markdown]
# ## Tri-Gram relative frequencies

# %%
tri_gram_df = n_gram_frequency(articles, 'summary', ngram_range=(3, 3), col_name='tri-gram')

tri_gram_rel_df = n_gram_frequency(articles[articles.relevant == True], 'summary', ngram_range=(3, 3), col_name='tri-gram')

tri_gram_nrel_df = n_gram_frequency(articles[articles.relevant == False], 'summary', ngram_range=(3, 3), col_name='tri-gram')

# %%
tri_gram_df = tri_gram_df.merge(tri_gram_rel_df.rename(columns={"frequency": "freq_relevant"}), left_on='tri-gram', right_on='tri-gram', how='left')
tri_gram_df = tri_gram_df.merge(tri_gram_nrel_df.rename(columns={"frequency": "freq_non_relevant"}), left_on='tri-gram', right_on='tri-gram', how='left')

# fill na with 0 for tri-grams that are not in relevant or non-relevant
tri_gram_df.fillna(0, inplace=True)

tri_gram_df['freq_relevant_ratio'] = tri_gram_df['freq_relevant'] / articles[articles.relevant == True].shape[0]
tri_gram_df['freq_non_relevant_ratio'] = tri_gram_df['freq_non_relevant'] / articles[articles.relevant == False].shape[0]

tri_gram_df['diff'] = np.abs(tri_gram_df['freq_relevant_ratio'] - tri_gram_df['freq_non_relevant_ratio'])

tri_gram_df['relevant_class'] = tri_gram_df['freq_relevant_ratio'] > tri_gram_df['freq_non_relevant_ratio']

# %%
tri_gram_df[tri_gram_df['relevant_class'] == True].sort_values(by='diff', ascending=False).head(20)
# Out:
#                                         tri-gram  frequency  freq_relevant  \
# 14595                     central nervous system        238          228.0
# 36427  experimental autoimmune encephalomyelitis        176          175.0
# 8461            autoimmune encephalomyelitis eae        148          147.0
# 66949                         nervous system cns        128          125.0
# 28168                    disease central nervous         61           59.0
# 62163                   model multiple sclerosis         46           46.0
# 59985                      mesenchymal stem cell         34           34.0
# 33700                encephalomyelitis eae mouse         30           30.0
# 64924              multiple sclerosis autoimmune         29           29.0
# 28541                 disease multiple sclerosis         65           57.0
# 70700             oligodendrocyte precursor cell         29           28.0
# 65755        myelin oligodendrocyte glycoprotein         24           24.0
# 70714            oligodendrocyte progenitor cell         24           24.0
# 97613                              stem cell msc         23           23.0
# 62044              model experimental autoimmune         23           23.0
# 64950                 multiple sclerosis chronic         42           38.0
# 76716                        play important role         22           22.0
# 33698                encephalomyelitis eae model         22           22.0
# 24999              demyelinating disease central         21           21.0
# 5230                       animal model multiple         21           21.0
#
#        freq_non_relevant  freq_relevant_ratio  freq_non_relevant_ratio  \
# 14595               10.0             0.266044                 0.046296
# 36427                1.0             0.204201                 0.004630
# 8461                 1.0             0.171529                 0.004630
# 66949                3.0             0.145858                 0.013889
# 28168                2.0             0.068845                 0.009259
# 62163                0.0             0.053676                 0.000000
# 59985                0.0             0.039673                 0.000000
# 33700                0.0             0.035006                 0.000000
# 64924                0.0             0.033839                 0.000000
# 28541                8.0             0.066511                 0.037037
# 70700                1.0             0.032672                 0.004630
# 65755                0.0             0.028005                 0.000000
# 70714                0.0             0.028005                 0.000000
# 97613                0.0             0.026838                 0.000000
# 62044                0.0             0.026838                 0.000000
# 64950                4.0             0.044341                 0.018519
# 76716                0.0             0.025671                 0.000000
# 33698                0.0             0.025671                 0.000000
# 24999                0.0             0.024504                 0.000000
# 5230                 0.0             0.024504                 0.000000
#
#            diff  relevant_class
# 14595  0.219748            True
# 36427  0.199571            True
# 8461   0.166899            True
# 66949  0.131969            True
# 28168  0.059586            True
# 62163  0.053676            True
# 59985  0.039673            True
# 33700  0.035006            True
# 64924  0.033839            True
# 28541  0.029474            True
# 70700  0.028042            True
# 65755  0.028005            True
# 70714  0.028005            True
# 97613  0.026838            True
# 62044  0.026838            True
# 64950  0.025822            True
# 76716  0.025671            True
# 33698  0.025671            True
# 24999  0.024504            True
# 5230   0.024504            True

# %%
tri_gram_df[tri_gram_df['relevant_class'] == False].sort_values(by='diff', ascending=False).head(20)
# Out:
#                                 tri-gram  frequency  freq_relevant  \
# 65230            multiple sclerosis pwms         22            8.0
# 75029          people multiple sclerosis         27           13.0
# 1623          acute respiratory syndrome         12            4.0
# 93582           severe acute respiratory         12            4.0
# 87938   respiratory syndrome coronavirus          9            2.0
# 11191                    body mass index          5            1.0
# 96632            spectrum disorder nmosd          5            1.0
# 82609                   quality life qol          7            3.0
# 104131                third vaccine dose          3            0.0
# 56371       logistic regression analysis          3            0.0
# 101796      systematic review literature          3            0.0
# 2069                    adjusted age sex          3            0.0
# 36744                expressed gene degs          3            0.0
# 101277  syndrome coronavirus vaccination          3            0.0
# 63068                  month second dose          3            0.0
# 71451           optica spectrum disorder          8            4.0
# 101798    systematic review metaanalysis          8            4.0
# 65263             multiple sclerosis rms          4            1.0
# 58175                     mass index bmi          4            1.0
# 94351      showed significant difference          9            5.0
#
#         freq_non_relevant  freq_relevant_ratio  freq_non_relevant_ratio  \
# 65230                14.0             0.009335                 0.064815
# 75029                14.0             0.015169                 0.064815
# 1623                  8.0             0.004667                 0.037037
# 93582                 8.0             0.004667                 0.037037
# 87938                 7.0             0.002334                 0.032407
# 11191                 4.0             0.001167                 0.018519
# 96632                 4.0             0.001167                 0.018519
# 82609                 4.0             0.003501                 0.018519
# 104131                3.0             0.000000                 0.013889
# 56371                 3.0             0.000000                 0.013889
# 101796                3.0             0.000000                 0.013889
# 2069                  3.0             0.000000                 0.013889
# 36744                 3.0             0.000000                 0.013889
# 101277                3.0             0.000000                 0.013889
# 63068                 3.0             0.000000                 0.013889
# 71451                 4.0             0.004667                 0.018519
# 101798                4.0             0.004667                 0.018519
# 65263                 3.0             0.001167                 0.013889
# 58175                 3.0             0.001167                 0.013889
# 94351                 4.0             0.005834                 0.018519
#
#             diff  relevant_class
# 65230   0.055480           False
# 75029   0.049646           False
# 1623    0.032370           False
# 93582   0.032370           False
# 87938   0.030074           False
# 11191   0.017352           False
# 96632   0.017352           False
# 82609   0.015018           False
# 104131  0.013889           False
# 56371   0.013889           False
# 101796  0.013889           False
# 2069    0.013889           False
# 36744   0.013889           False
# 101277  0.013889           False
# 63068   0.013889           False
# 71451   0.013851           False
# 101798  0.013851           False
# 65263   0.012722           False
# 58175   0.012722           False
# 94351   0.012684           False

# %% [markdown]
# ### Which tri-grams appear only in each class?

# %%
# relevant class
tri_gram_df[(tri_gram_df['relevant_class'] == True) & (tri_gram_df['freq_non_relevant'] == 0)].sort_values(by='diff', ascending=False).head(20)
# Out:
#                                   tri-gram  frequency  freq_relevant  \
# 62163             model multiple sclerosis         46           46.0
# 59985                mesenchymal stem cell         34           34.0
# 33700          encephalomyelitis eae mouse         30           30.0
# 64924        multiple sclerosis autoimmune         29           29.0
# 65755  myelin oligodendrocyte glycoprotein         24           24.0
# 70714      oligodendrocyte progenitor cell         24           24.0
# 97613                        stem cell msc         23           23.0
# 62044        model experimental autoimmune         23           23.0
# 76716                  play important role         22           22.0
# 33698          encephalomyelitis eae model         22           22.0
# 24999        demyelinating disease central         21           21.0
# 5230                 animal model multiple         21           21.0
# 31268                      eae mouse model         20           20.0
# 30953                     eae animal model         20           20.0
# 65085      multiple sclerosis inflammatory         17           17.0
# 33664         encephalomyelitis eae animal         17           17.0
# 11004               bloodbrain barrier bbb         16           16.0
# 76707                    play crucial role         15           15.0
# 56999                      luxol fast blue         14           14.0
# 79957                 progenitor cell opcs         14           14.0
#
#        freq_non_relevant  freq_relevant_ratio  freq_non_relevant_ratio  \
# 62163                0.0             0.053676                      0.0
# 59985                0.0             0.039673                      0.0
# 33700                0.0             0.035006                      0.0
# 64924                0.0             0.033839                      0.0
# 65755                0.0             0.028005                      0.0
# 70714                0.0             0.028005                      0.0
# 97613                0.0             0.026838                      0.0
# 62044                0.0             0.026838                      0.0
# 76716                0.0             0.025671                      0.0
# 33698                0.0             0.025671                      0.0
# 24999                0.0             0.024504                      0.0
# 5230                 0.0             0.024504                      0.0
# 31268                0.0             0.023337                      0.0
# 30953                0.0             0.023337                      0.0
# 65085                0.0             0.019837                      0.0
# 33664                0.0             0.019837                      0.0
# 11004                0.0             0.018670                      0.0
# 76707                0.0             0.017503                      0.0
# 56999                0.0             0.016336                      0.0
# 79957                0.0             0.016336                      0.0
#
#            diff  relevant_class
# 62163  0.053676            True
# 59985  0.039673            True
# 33700  0.035006            True
# 64924  0.033839            True
# 65755  0.028005            True
# 70714  0.028005            True
# 97613  0.026838            True
# 62044  0.026838            True
# 76716  0.025671            True
# 33698  0.025671            True
# 24999  0.024504            True
# 5230   0.024504            True
# 31268  0.023337            True
# 30953  0.023337            True
# 65085  0.019837            True
# 33664  0.019837            True
# 11004  0.018670            True
# 76707  0.017503            True
# 56999  0.016336            True
# 79957  0.016336            True

# %%
# non-relevant class
tri_gram_df[(tri_gram_df['relevant_class'] == False) & (tri_gram_df['freq_relevant'] == 0)].sort_values(by='diff', ascending=False).head(20)
# Out:
#                                 tri-gram  frequency  freq_relevant  \
# 56371       logistic regression analysis          3            0.0
# 63068                  month second dose          3            0.0
# 104131                third vaccine dose          3            0.0
# 2069                    adjusted age sex          3            0.0
# 101277  syndrome coronavirus vaccination          3            0.0
# 36744                expressed gene degs          3            0.0
# 101796      systematic review literature          3            0.0
# 53433            joanna briggs institute          2            0.0
# 88722                   result study may          2            0.0
# 29894                   dos mrna vaccine          2            0.0
# 45545            humoral immune response          2            0.0
# 99018                     study may help          2            0.0
# 80683         promising treatment option          2            0.0
# 2787                       age body mass          2            0.0
# 21977   crosssectional study participant          2            0.0
# 16349           clinical outcome patient          2            0.0
# 6769           arterial hypertension pah          2            0.0
# 6770              arterial pressure mmhg          2            0.0
# 64157         mrcompatible ergometer ran          2            0.0
# 19090            conclusion overall high          2            0.0
#
#         freq_non_relevant  freq_relevant_ratio  freq_non_relevant_ratio  \
# 56371                 3.0                  0.0                 0.013889
# 63068                 3.0                  0.0                 0.013889
# 104131                3.0                  0.0                 0.013889
# 2069                  3.0                  0.0                 0.013889
# 101277                3.0                  0.0                 0.013889
# 36744                 3.0                  0.0                 0.013889
# 101796                3.0                  0.0                 0.013889
# 53433                 2.0                  0.0                 0.009259
# 88722                 2.0                  0.0                 0.009259
# 29894                 2.0                  0.0                 0.009259
# 45545                 2.0                  0.0                 0.009259
# 99018                 2.0                  0.0                 0.009259
# 80683                 2.0                  0.0                 0.009259
# 2787                  2.0                  0.0                 0.009259
# 21977                 2.0                  0.0                 0.009259
# 16349                 2.0                  0.0                 0.009259
# 6769                  2.0                  0.0                 0.009259
# 6770                  2.0                  0.0                 0.009259
# 64157                 2.0                  0.0                 0.009259
# 19090                 2.0                  0.0                 0.009259
#
#             diff  relevant_class
# 56371   0.013889           False
# 63068   0.013889           False
# 104131  0.013889           False
# 2069    0.013889           False
# 101277  0.013889           False
# 36744   0.013889           False
# 101796  0.013889           False
# 53433   0.009259           False
# 88722   0.009259           False
# 29894   0.009259           False
# 45545   0.009259           False
# 99018   0.009259           False
# 80683   0.009259           False
# 2787    0.009259           False
# 21977   0.009259           False
# 16349   0.009259           False
# 6769    0.009259           False
# 6770    0.009259           False
# 64157   0.009259           False
# 19090   0.009259           False

# %% [markdown]
# ### Most frequent tri-grams in each class (absolute frequency)

# %%
# relevant class
tri_gram_df[tri_gram_df.relevant_class == True].sort_values(by='freq_relevant', ascending=False).head(20)[['tri-gram', 'freq_relevant']].reset_index(drop=True)
# Out:
#                                      tri-gram  freq_relevant
# 0                      central nervous system          228.0
# 1   experimental autoimmune encephalomyelitis          175.0
# 2            autoimmune encephalomyelitis eae          147.0
# 3                          nervous system cns          125.0
# 4                     disease central nervous           59.0
# 5                  disease multiple sclerosis           57.0
# 6                    model multiple sclerosis           46.0
# 7                  patient multiple sclerosis           41.0
# 8                  multiple sclerosis chronic           38.0
# 9                       mesenchymal stem cell           34.0
# 10                    disability status scale           32.0
# 11                encephalomyelitis eae mouse           30.0
# 12              multiple sclerosis autoimmune           29.0
# 13             oligodendrocyte precursor cell           28.0
# 14               treatment multiple sclerosis           25.0
# 15            oligodendrocyte progenitor cell           24.0
# 16                         spinal cord injury           24.0
# 17        myelin oligodendrocyte glycoprotein           24.0
# 18              amyotrophic lateral sclerosis           24.0
# 19                       myelin basic protein           24.0

# %%
# non-relevant class
tri_gram_df[tri_gram_df.relevant_class == False].sort_values(by='freq_non_relevant', ascending=False).head(20)[['tri-gram', 'freq_non_relevant']].reset_index(drop=True)
# Out:
#                                  tri-gram  freq_non_relevant
# 0                 multiple sclerosis pwms               14.0
# 1               people multiple sclerosis               14.0
# 2                severe acute respiratory                8.0
# 3   relapsingremitting multiple sclerosis                8.0
# 4              expanded disability status                8.0
# 5              acute respiratory syndrome                8.0
# 6        respiratory syndrome coronavirus                7.0
# 7              multiple sclerosis patient                5.0
# 8           showed significant difference                4.0
# 9                         scale eds score                4.0
# 10                       quality life qol                4.0
# 11               optica spectrum disorder                4.0
# 12         systematic review metaanalysis                4.0
# 13                spectrum disorder nmosd                4.0
# 14          neuromyelitis optica spectrum                4.0
# 15                  serious adverse event                4.0
# 16                        body mass index                4.0
# 17    patient relapsingremitting multiple                4.0
# 18           significant difference found                3.0
# 19                 confidence interval ci                3.0
